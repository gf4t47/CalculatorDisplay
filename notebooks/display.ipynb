# %%
# %matplotlib inline
from src.main import display

# %%
display(12345678901234567890)
# Out:
# width=24 offset=6 height=48

# %%
display(1)
# Out:
# width=80 offset=20 height=160

# %%
display(0)
# Out:
# width=80 offset=20 height=160
